# %% [markdown]
# # <center> Adult Dataset-Preprocessing Part </center>
#
# ### INDEX
# <ul>
# <li><a href="#Preprocessing">Data Preprocessing </a></li>
# </ul>

# %% [markdown]
# <a id="Preprocessing"> </a>
# ## Data Preprocessing

# %%
# importing needed libraries
import numpy as np
import pandas as pd
from datasist.structdata import detect_outliers

# %%
df=pd.read_csv('../data/processed/Adults_salaries_EDA.csv')
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 45170   27       Private  257302    Assoc-acdm               12
# 45171   40       Private  154374       HS-grad                9
# 45172   58       Private  151910       HS-grad                9
# 45173   22       Private  201490       HS-grad                9
# 45174   52  Self-emp-inc  287927       HS-grad                9
#
#       marital-status         occupation   relationship   race  gender  \
# 0             single  Machine-op-inspct      Own-child  Black    Male
# ...

# %%
num_col=df.select_dtypes(include='number')
num_col=num_col.columns
num_col
# Out:
# Index(['age', 'fnlwgt', 'educational-num', 'capital-gain', 'capital-loss',
#        'hours-per-week'],
#       dtype='object')

# %%
len(detect_outliers(df,0,num_col))
# Out:
# 17495

# %%
len(detect_outliers(df,0,['age']))
# Out:
# 268

# %%
incid_outliers=detect_outliers(df,0,['age'])
incid_outliers
# Out:
# [215,
#  831,
#  879,
#  953,
#  994,
#  1266,
#  1289,
#  1923,
#  2114,
#  2118,
#  2445,
#  2450,
#  2755,
#  2820,
#  3233,
#  3380,
#  3401,
#  3453,
#  3459,
#  3530,
#  3930,
#  4028,
#  4043,
#  4107,
#  4313,
#  4836,
#  5072,
#  5329,
#  5401,
#  5550,
#  6030,
#  6074,
#  6243,
#  6322,
#  6385,
#  6426,
#  6443,
#  6446,
#  6518,
#  6618,
#  6858,
#  6863,
#  6974,
#  6981,
#  6989,
#  7007,
#  7080,
#  7337,
#  7599,
#  7679,
#  7787,
#  7873,
#  8077,
#  8278,
#  8304,
#  8339,
#  8357,
#  8575,
#  8577,
#  8943,
#  9016,
#  9128,
#  9272,
#  9420,
#  9440,
#  9640,
#  9920,
#  10010,
#  10042,
#  10421,
#  10447,
#  10484,
#  10559,
#  10962,
#  11056,
#  11162,
#  11260,
#  11324,
#  11337,
#  11518,
#  11748,
#  12061,
#  12437,
#  12458,
#  12917,
#  13199,
#  13234,
#  13357,
#  13481,
#  13502,
#  13632,
#  13672,
#  13836,
#  13961,
#  14104,
#  14727,
#  14754,
#  14790,
#  14887,
#  14927,
#  15123,
#  15147,
#  15261,
#  15348,
#  15356,
#  15900,
#  15956,
# ...

# %%
df['age'].iloc[899]
# Out:
# 40

# %% [markdown]
# ### i go with not deleting or replacing outliers cause they represent actual values like age in addition to they are represnt a huge part from my dataset

# %% [markdown]
# I Will drop native Country column

# %%
df.drop(['native-country'],axis=1,inplace=True)

# %%
cat_col=df.select_dtypes('object').columns
cat_col
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'gender', 'income'],
#       dtype='object')

# %%
df=pd.get_dummies(df,columns=cat_col,drop_first=True)
df
# Out:
#        age  fnlwgt  educational-num  capital-gain  capital-loss  \
# 0       25  226802                7             0             0
# 1       38   89814                9             0             0
# 2       28  336951               12             0             0
# 3       44  160323               10          7688             0
# 4       34  198693                6             0             0
# ...    ...     ...              ...           ...           ...
# 45170   27  257302               12             0             0
# 45171   40  154374                9             0             0
# 45172   58  151910                9             0             0
# 45173   22  201490                9             0             0
# 45174   52  287927                9         15024             0
#
#        hours-per-week  workclass_Local-gov  workclass_Private  \
# 0                  40                    0                  1
# 1                  50                    0                  1
# ...

# %%
df.to_csv('../data/processed/Adult_Salries_processed.csv',index=False, index_label=None)
